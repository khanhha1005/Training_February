# %%
# %cd /Users/trancatkhanh/Downloads/ezgif-5-5700dd16ee-jpg
import cv2
import matplotlib.pyplot as plt
plt.style.use('seaborn')
for i in range(1, 100,10):
    if i < 10:
        img = cv2.imread("ezgif-frame-00"+str(i)+'.jpg')
    else:
        img = cv2.imread('ezgif-frame-0'+str(i)+'.jpg')
    img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img_invert = cv2.bitwise_not(img_gray)
    img_smoothing = cv2.GaussianBlur(img_invert, (21, 21),sigmaX=0, sigmaY=0)
    final = cv2.divide(img_gray, 255 - img_smoothing, scale=255)
    plt.figure(figsize=(8,8))
    plt.imshow(final,cmap="gray")
    plt.axis("off")
    plt.title("Final Sketch Image")
    plt.show()
    plt.savefig(str(i)+'.png')
for i in range(100,150,10):
    img = cv2.imread("ezgif-frame-"+str(i)+".jpg")
    img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img_invert = cv2.bitwise_not(img_gray)
    img_smoothing = cv2.GaussianBlur(img_invert, (21, 21),sigmaX=0, sigmaY=0)
    final = cv2.divide(img_gray, 255 - img_smoothing, scale=255)
    plt.figure(figsize=(8,8))
    plt.imshow(final,cmap="gray")
    plt.axis("off")
    plt.title("Final Sketch Image")
    plt.show()
    plt.savefig(str(i)+'.png')
# Out:
# /Users/trancatkhanh/Downloads/ezgif-5-5700dd16ee-jpg

# %%
# %cd /Users/trancatkhanh/Downloads/ezgif-5-0dba619ff0-jpg

import cv2
import matplotlib.pyplot as plt
plt.style.use('seaborn')
for i in range(1, 100,10):
    if i < 10:
        img = cv2.imread("ezgif-frame-00"+str(i)+'.jpg')
    else:
        img = cv2.imread('ezgif-frame-0'+str(i)+'.jpg')
    img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img_invert = cv2.bitwise_not(img_gray)
    img_smoothing = cv2.GaussianBlur(img_invert, (21, 21),sigmaX=0, sigmaY=0)
    final = cv2.divide(img_gray, 255 - img_smoothing, scale=255)
    plt.figure(figsize=(8,8))
    plt.imshow(final,cmap="gray")
    plt.axis("off")
    plt.title("Final Sketch Image")
    plt.show()
for i in range(100,150,20):
    img = cv2.imread("ezgif-frame-"+str(i)+".jpg")
    img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img_invert = cv2.bitwise_not(img_gray)
    img_smoothing = cv2.GaussianBlur(img_invert, (21, 21),sigmaX=0, sigmaY=0)
    final = cv2.divide(img_gray, 255 - img_smoothing, scale=255)
    plt.figure(figsize=(8,8))
    plt.imshow(final,cmap="gray")
    plt.axis("off")
    plt.title("Final Sketch Image")
    plt.show()
# Out:
# /Users/trancatkhanh/Downloads/ezgif-5-0dba619ff0-jpg

# %%
# put all the above figure into 1 figure
import cv2
import matplotlib.pyplot as plt
import numpy as np
plt.style.use('seaborn')
fig = plt.figure(figsize=(30,30))
l = 1
for i in range(1, 100,10):
    if i < 10:
        img = cv2.imread("ezgif-frame-00"+str(i)+'.jpg')
    else:
        img = cv2.imread('ezgif-frame-0'+str(i)+'.jpg')
    img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img_invert = cv2.bitwise_not(img_gray)
    img_smoothing = cv2.GaussianBlur(img_invert, (21, 21),sigmaX=0, sigmaY=0)
    final = cv2.divide(img_gray, 255 - img_smoothing, scale=255)
    fig.add_subplot(1,10,l)
    plt.imshow(final,cmap="gray")
    plt.axis("off")
    l+=1
    plt.title("Final Sketch Image")
# for i in range(100,150,20):
#     img = cv2.imread("ezgif-frame-"+str(i)+".jpg")
#     img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
#     img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#     img_invert = cv2.bitwise_not(img_gray)
#     img_smoothing = cv2.GaussianBlur(img_invert, (21, 21),sigmaX=0, sigmaY=0)
#     final = cv2.divide(img_gray, 255 - img_smoothing, scale=255)
#     fig.add_subplot(10,10,i)
#     plt.imshow(final,cmap="gray")
#     plt.axis("off")
#     plt.title("Final Sketch Image")
# plt.show()
